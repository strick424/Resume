# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from shapely import geometry
import random
import math
# %matplotlib inline

# %%
data = pd.read_csv('boundingbox.csv')
data['lon direction']=data['\ufefflon direction'] 
del data['\ufefflon direction']

# %%
brunei = [5.033182, 115.086013]
phillipines = [14.790988, 120.242715]
singapore = [1.461519, 103.831384]
vietnam = [11.901643, 109.170094]
bases = [brunei,phillipines,singapore,vietnam]

# %%
def degMinSecToDecimal(deg, mn, sec):
    """ convert (degrees,minutes,seconds) to decimal-degrees """
    decimal = deg + (mn/60.0) + (sec/3600.0)
    return decimal

def calc_distance(lat1, lon1, lat2, lon2):
    '''This function calculates the distance between two coordinates. It takes 2 lat/lon pairs of coordinates in 
    decimal representation and first converts them to radians. The coordinates must already be in there decimal 
    representation to be used as inputs. It then calculates the distance between the two coordinates using the
    great circle distance equation from the reference. From there it converts that distance from radians back to nm.'''
    rlat1 = deg2rad(lat1) #converts lat/longs from degrees to radians
    rlon1 = deg2rad(lon1)
    rlat2 = deg2rad(lat2)
    rlon2 = deg2rad(lon2)
    d = math.acos(math.sin(rlat1) * math.sin(rlat2) + math.cos(rlat1) * math.cos(rlat2) * math.cos(rlon1 - rlon2))
    # calculates distance between two points in radians. formula provided in reference
    nm = rad2nm(d) # this converts the distance from radians to nm
    return nm
#end of calc_distance

def rad2nm (radians):
    '''This function converts a distance in radians into nautical miles. It will take one input in radians.'''
    nm = ((180 * 60) / math.pi) * radians
    return nm #returns the distance in nm
#end of rad2nm


def deg2rad (degrees):
    '''This function will convert a coordinate location in decimal representation in degrees to its value
    in radians. The input is the decimal degree location of a single coordinate.'''
    radians = degrees * ((math.pi)/180)
    return radians #returns the value in radians
# end of deg2rad

# %%
boxpoints =[]
for index,row in data.iterrows():
    lat = degMinSecToDecimal(row['lat degrees '],row['lat minutes '],row['lat seconds'])
    lon = degMinSecToDecimal(row['lon degrees'],row['lon minutes'],row['lon seconds'])
    if row['lat direction']=='S':
        lat = -lat
    if row['lon direction']=='W':
        lon= -lon
    boxpoints.append([lat,lon])
    
poly = geometry.Polygon(boxpoints)
#poly.wkt

# %%
def get_random_point_in_polygon(poly):
    (minx, miny, maxx, maxy) = poly.bounds
    test = False
    while test == False:
        p = geometry.Point(random.uniform(minx, maxx), random.uniform(miny, maxy))
        if poly.contains(p):
            #print(p)
            test = True
            return p

# %%
def initial_resupply_locations(rs_ship,rs_ship_dict,maxdistance):
    test=False
    while test == False:
        point = get_random_point_in_polygon(poly)
        loc = calc_distance(point.x,point.y,rs_ship_dict[rs_ship][5][0],rs_ship_dict[rs_ship][5][1])
        if loc <= maxdistance:
            test=True
            goodpoint=point
    return goodpoint

# %%
def resupply_back_out(rs,rs_ship_dict,maxdistance,speed):
    test=False
    while test == False:
        point = get_random_point_in_polygon(poly)
        distance = calc_distance(point.x,point.y,rs_ship_dict[rs][5][0],rs_ship_dict[rs][5][1])
        if distance <= maxdistance:
            test=True
            goodpoint=point
            time=distance/speed
    return time,goodpoint

# %%
def resupply_back_out2(patrol,ship_dict,rs,rs_ship_dict,maxdistance,speed):
    test=False
    while test == False:
        point = get_random_point_in_polygon(poly)
        distance = calc_distance(point.x,point.y,rs_ship_dict[rs][5][0],rs_ship_dict[rs][5][1])
        if distance <= maxdistance:
            test=True
            goodpoint=point
            bhdistance = calc_distance(goodpoint.x,goodpoint.y,ship_dict[patrol][4].x,ship_dict[patrol][4].y)
            time=bhdistance/speed
    return time,goodpoint

# %%
def patrol_needs_fuel(ship,ship_dict,rs_ship_dict,avail_rs_list,speed):
    ship_point = ship_dict[ship][4]
    distance_list = []
    for rs_ship in avail_rs_list:
        rs_loc = rs_ship_dict[rs_ship][4]
        distance_list.append([rs_ship,calc_distance(ship_point.x,ship_point.y,rs_loc.x,rs_loc.y)])
    rs,dist = find_min_distance(distance_list)
    time = dist/speed
    return rs,time

# %%
def find_distancelist(ship,ship_dict,rs_ship_dict,avail_rs_list):
    ship_point = ship_dict[ship][4]
    distance_list = []
    fuel_need = ship_dict[ship][2]-ship_dict[ship][0]
    for rs_ship in avail_rs_list:
        if rs_ship_dict[rs_ship][0] >= fuel_need:
            rs_loc = rs_ship_dict[rs_ship][4]
            distance_list.append([rs_ship,calc_distance(ship_point.x,ship_point.y,rs_loc.x,rs_loc.y)])
    return distance_list

# %%
def find_min_distance(distancelist,speed):
    min_distance = 1000000
    #min_ship = line[0]
    for line in distancelist:
        if line[1] < min_distance:
            min_distance = line[1]
            min_ship = line[0]
            time = min_distance/speed
    return min_ship,time,min_distance

# %%
def patrol_back_out(patrol_ship,ship_dict,maxdistance,speed):
    test=False
    while test == False:
        point = get_random_point_in_polygon(poly)
        distance = calc_distance(point.x,point.y,ship_dict[patrol_ship][4].x,ship_dict[patrol_ship][4].y)
        if distance <= maxdistance:
            test=True
            goodpoint=point
            time = distance/speed
    return goodpoint,time

# %%
def resupply_ship_needs_fuel(patrol_ship,ship_dict,rs,rs_ship_dict,speed):
    point= ship_dict[patrol_ship][4]
    distance = calc_distance(point.x,point.y,rs_ship_dict[rs][5][0],rs_ship_dict[rs][5][1])
    time = distance/speed
    return time

# %%
point=get_random_point_in_polygon(poly)
#print(point)

# %%
from queue import PriorityQueue
import abc

class SimpleKit:
    """
    To create a SimpleKit model:
        Your model class must be a subclass of SimpleKit.
        Your constructor (__init__()) must call SimpleKit.__init__(self).
        You must override the abstract init() method to start your model.
    Note:
        Your model cannot implement methods named run(), schedule(), or halt().
    """
    __metaclass__ = abc.ABCMeta

    def __init__(self):
        """Initialize a pending events list and set model_time to 0."""
        self.event_list = PriorityQueue()
        self.model_time = 0.0
    
    @abc.abstractmethod
    def init(self):
        """This abstract method must be overridden in your model class."""

    def run(self):
        """Execute the model logic."""
        self.init()
        while not self.event_list.empty():
            event_notice = self.event_list.get()
            self.model_time = event_notice[0]
            event_notice[1](*event_notice[2:])

    def schedule(self, event, delay, *args):
        """Add an event to the pending events.

        Args:
            event: The name of the event method to be scheduled.
            delay: The amount of model time by which to delay the execution.
            args: (optional) Any arguments required by the event.
        """
        if delay < 0:
            raise RuntimeError('Negative delay is not allowed.')
        event_notice = [delay + self.model_time, event] + list(args)
        self.event_list.put(event_notice)
        print(self.event_list.values)
    
    def halt(self):
        """Terminate a simulation run by clearing the pending events list."""
        while not self.event_list.empty():
            self.event_list.get()

# %%
from simplekit import SimpleKit
import numpy as numpy
import math
import csv

class Logistic_Model(SimpleKit):
    """Implementation of a Maritime Logistics System for refueling ."""

    def __init__(self, outfile):
        """Construct an instance of the M/M/k."""
        SimpleKit.__init__(self)        
        
        #initialize all values of self for the system
        #Demand values
        self.CSG_cap_fuel = 17000+2200*3+2100
        self.DDG_cap_fuel = 2629
        self.CG_cap_fuel = 3758
        #self.CVN_cap_ammo = 0
        self.CSG_cap_ammo = 268
        self.DDG_cap_ammo = 26
        self.CG_cap_ammo = 18
        
        #Resupply Ship Values
            #FCS:
        self.TAOE_cap_fuel = 177000 #barrels
        self.TAOE_cap_ammo = 1800 #tons
            
            #Lewis and Clark:
        self.TAKE_cap_fuel = 23450 #barrels
        self.TAKE_cap_ammo = 6000 #tons 
            
            #CLS
        self.CLS5000_cap_fuel = 2900 #barrels
        self.CLS5000_cap_ammo = 500  #tons
        
        #self.speed = 18 #knots
        #create and output file based on the given outfile name
        b = open(outfile, 'w', newline='') 
        fieldnames = ['Model_Time', 'Event', "Ship", "Ship Fuel Qty",'Ship Ammo Qty',
                      "Resupply Ship", "Resupply Fuel Qty",'Resupply Ammo Qty']
        self.outcsvfile = csv.DictWriter(b, fieldnames=fieldnames)
        self.outcsvfile.writeheader()
     
    
    def init(self):
        """Initialize all state variables, schedule first demand."""
        
        #Demand ships
        self.ship_list = ['CSG', #carrier
                          'DDG_62', 'DDG_63', 'DDG_85', 'DDG_89', #destroyers
                          'CG_62', 'CG_67'] #cruisers
        
                         #'ship'  : [fuel level,        ammo level,        fuel capacity,     ammo capacity     , location(tuple)]     
        self.ship_dict = {'CSG': [self.CSG_cap_fuel, self.CSG_cap_ammo, self.CSG_cap_fuel, self.CSG_cap_ammo, get_random_point_in_polygon(poly)], 
                          #'DDG_52': [self.DDG_cap_fuel, self.DDG_cap_ammo, self.DDG_cap_fuel, self.DDG_cap_ammo, get_random_point_in_polygon(poly)],
                          #'DDG_54': [self.DDG_cap_fuel, self.DDG_cap_ammo, self.DDG_cap_fuel, self.DDG_cap_ammo, get_random_point_in_polygon(poly)],
                          #'DDG_56': [self.DDG_cap_fuel, self.DDG_cap_ammo, self.DDG_cap_fuel, self.DDG_cap_ammo, get_random_point_in_polygon(poly)],
                          'DDG_62': [self.DDG_cap_fuel, self.DDG_cap_ammo, self.DDG_cap_fuel, self.DDG_cap_ammo, get_random_point_in_polygon(poly)],
                          'DDG_63': [self.DDG_cap_fuel, self.DDG_cap_ammo, self.DDG_cap_fuel, self.DDG_cap_ammo, get_random_point_in_polygon(poly)],
                          'DDG_85': [self.DDG_cap_fuel, self.DDG_cap_ammo, self.DDG_cap_fuel, self.DDG_cap_ammo, get_random_point_in_polygon(poly)],
                          'DDG_89': [self.DDG_cap_fuel, self.DDG_cap_ammo, self.DDG_cap_fuel, self.DDG_cap_ammo, get_random_point_in_polygon(poly)],
                          #'CG_54':  [self.CG_cap_fuel,  self.CG_cap_ammo,  self.CG_cap_fuel,  self.CG_cap_ammo, get_random_point_in_polygon(poly)],
                          'CG_62':  [self.CG_cap_fuel,  self.CG_cap_ammo,  self.CG_cap_fuel,  self.CG_cap_ammo, get_random_point_in_polygon(poly)],
                          'CG_67':  [self.CG_cap_fuel,  self.CG_cap_ammo,  self.CG_cap_fuel,  self.CG_cap_ammo, get_random_point_in_polygon(poly)]} 
        
        #Resupply ships:
        self.rs_ship_list = ['T_AOE_6', 'T_AKE_4']#,'T_AOE_8', 'T_AKE_3', ] 
                             #'CLS_1','CLS_2','CLS_3','CLS_4'] 
        
                            #'ship'    : [fuel level,        ammo level,        fuel capacity,     ammo capacity]
        self.rs_ship_dict = {'T_AOE_6': [self.TAOE_cap_fuel, self.TAOE_cap_ammo, self.TAOE_cap_fuel, self.TAOE_cap_ammo, [0,0],brunei],
                             #'T_AOE_8': [self.TAOE_cap_fuel, self.TAOE_cap_ammo, self.TAOE_cap_fuel, self.TAOE_cap_ammo, [0,0],phillipines],
                             #'T_AKE_3': [self.TAKE_cap_fuel, self.TAKE_cap_ammo, self.TAKE_cap_fuel, self.TAKE_cap_ammo, [0,0],brunei],
                             'T_AKE_4': [self.TAKE_cap_fuel, self.TAKE_cap_ammo, self.TAKE_cap_fuel, self.TAKE_cap_ammo, [0,0],vietnam]}
                             #'CLS_1': [self.CLS5000_cap_fuel, self.CLS5000_cap_ammo, self.CLS5000_cap_fuel, self.CLS5000_cap_ammo, [0,0],vietnam],
                             #'CLS_2': [self.CLS5000_cap_fuel, self.CLS5000_cap_ammo, self.CLS5000_cap_fuel, self.CLS5000_cap_ammo, [0,0],phillipines],
                             #'CLS_3': [self.CLS5000_cap_fuel, self.CLS5000_cap_ammo, self.CLS5000_cap_fuel, self.CLS5000_cap_ammo, [0,0],brunei],
                             #'CLS_4': [self.CLS5000_cap_fuel, self.CLS5000_cap_ammo, self.CLS5000_cap_fuel, self.CLS5000_cap_ammo, [0,0],singapore]}
        
        #resupply ships available to resupply
        self.avail_rs_list = ['T_AOE_6', 'T_AKE_4']#,'T_AOE_8', 'T_AKE_3', ] 
                             #'CLS_1','CLS_2','CLS_3','CLS_4'] 
        
        self.schedule(self.halt, 24*60)  #run the model for 15 days
        
        for ship in self.ship_list: #schedule when all ships run out of fuel and where they will be located 
            self.schedule(self.demand, random.uniform(96,144), ship)
        
        for rs_ship in self.rs_ship_list:
            self.rs_ship_dict[rs_ship][4] = initial_resupply_locations(rs_ship,self.rs_ship_dict,300)

        self.dumpState("Init", 'NA', 'NA', 'NA', 'NA','NA','NA')
    
    
    def demand(self,ship):
        """Check to determine if any ships need fuel/ammo"""
        self.ship_dict[ship][0]=0
        
        if len(self.avail_rs_list) == 0:
            self.schedule(self.demand, 1, ship) #no resupply ship is available, check back in an hour
            self.dumpState('!!Resupply Unavailable!!',ship,'NA','NA','NA','NA','NA') #surface ship can not be resupplied at the time
        else:
            dl = find_distancelist(ship,self.ship_dict,self.rs_ship_dict,self.avail_rs_list)
            if len(dl)== 0:
                self.schedule(self.demand, 1, ship) #no resupply ship is available, check back in an hour
                self.dumpState('!!Not big enough!!',ship,'NA','NA','NA','NA','NA')#surface ship can not be resupplied at the time
            else:
                rs,time,dist=find_min_distance(dl,18)
                self.avail_rs_list.remove(rs)
                self.schedule(self.resupply,time,ship,rs,dist)
                self.dumpState('Fuel Needed',ship,self.ship_dict[ship][0],self.ship_dict[ship][1],
                               rs,self.rs_ship_dict[rs][0],self.rs_ship_dict[rs][1])
                
    def resupply(self, ship, resupply,distance): 
        """Subtract fuel from resupply ship, reset fuel for surface ship, schedule both ships to go on patrol"""
        survival = random.uniform(0,1)
        if survival > 0.98:
            self.schedule(self.demand,1,ship)
            self.rs_ship_list.remove(resupply)
            self.dumpState('Resupply ship did not survive!!!!',ship,'NA','NA',resupply,'NA','NA')
        else:
            self.schedule(self.patrol, numpy.random.normal(4, 1), ship, resupply) 
            self.rs_ship_dict[resupply][1] -= self.ship_dict[ship][3] #subtract ammo from resupply
            self.rs_ship_dict[resupply][0] = self.rs_ship_dict[resupply][0] - self.ship_dict[ship][2] #subtract the fuel transferred from resupply ship
            self.ship_dict[ship][0] = self.ship_dict[ship][2] #reset the fuel guage for ship
            self.ship_dict[ship][1] = self.ship_dict[ship][3] #reset ammo for ship
            self.dumpState("Resupply Under Way", ship, self.ship_dict[ship][0],self.ship_dict[ship][1],
                           resupply, self.rs_ship_dict[resupply][0], self.rs_ship_dict[resupply][1])     
    
    def patrol(self, ship, resupply):
        """Schedule when the ship needs fuel and it's location at that time, check to see if the resupply ship needs fuel"""
        self.ship_dict[ship][4],time = patrol_back_out(ship,self.ship_dict,2000,18)
        
        self.schedule(self.demand, (random.uniform(48,72))+time, ship) #Schedule when the ship runs out of fuel!!! dictionary value based on avearge fuel rates 
        
        
        if (self.rs_ship_dict[resupply][0] <= 0.25*self.rs_ship_dict[resupply][2]) or (self.rs_ship_dict[resupply][1] <= 268): #check if the resupply ship needs fuel
            time = resupply_ship_needs_fuel(ship,self.ship_dict,resupply,self.rs_ship_dict,20)
            self.schedule(self.resupply_resupply, time, resupply) #schedule a time to resupply the resupply ship
            self.dumpState("Return to Base", 'NA', 'NA','NA', 
                           resupply, self.rs_ship_dict[resupply][0], self.rs_ship_dict[resupply][1])  
            self.dumpState("Patrolling", ship, self.ship_dict[ship][0],self.ship_dict[ship][1],
                           resupply, self.rs_ship_dict[resupply][0], self.rs_ship_dict[resupply][1])      
    
        else:
            #self.avail_rs_list.append(resupply)
            #resupply ship goes back to AO
            time,self.rs_ship_dict[resupply][4]=resupply_back_out2(ship,self.ship_dict,resupply,self.rs_ship_dict,300,20)
            self.schedule(self.resupply_available,time,resupply)
            self.dumpState("Patrolling", ship, self.ship_dict[ship][0],self.ship_dict[ship][1],
                           resupply, self.rs_ship_dict[resupply][0], self.rs_ship_dict[resupply][1])      
    
    def resupply_resupply(self, resupply):
        """Reset the resupply levels of the resupply ships, generate a location for it to travel to, append it to the available list"""
        self.rs_ship_dict[resupply][0] = self.rs_ship_dict[resupply][2] #resupply ship is topped back off
        self.rs_ship_dict[resupply][1] = self.rs_ship_dict[resupply][3] #ammo topped off
        time,self.rs_ship_dict[resupply][4] = resupply_back_out(resupply,self.rs_ship_dict,300,20)
        self.schedule(self.resupply_available,time,resupply)
        self.dumpState("Resupplying Resupply", "NA", "NA",'NA',
                       resupply, self.rs_ship_dict[resupply][0], self.rs_ship_dict[resupply][1])    
    def resupply_available(self,resupply):
        self.avail_rs_list.append(resupply)
        self.dumpState('Resupply Available','NA','NA','NA',resupply,'NA','NA')
        
    def dumpState(self, event, ship, ship_fuel, ship_ammo, resupply, resupply_fuel,resupply_ammo): #this state prints all values to the .csv file
        """Dump of the current state of the model."""
        self.outcsvfile.writerow({'Model_Time': float(self.model_time), 'Event': event, 
                                  'Ship':ship, 'Ship Fuel Qty': ship_fuel,'Ship Ammo Qty': ship_ammo, 
                                  'Resupply Ship': resupply,  'Resupply Fuel Qty': resupply_fuel,
                                  'Resupply Ammo Qty':resupply_ammo}) 
        print("Time:", self.model_time, "Event:", event,'Ship', ship, "Ship Fuel Qty:", ship_fuel,'Ship Ammo Qty:',ship_ammo,
              'Resupply Ship', resupply, "Resupply Fuel Qty:", resupply_fuel, 'Resupply Ammo Qty:',resupply_ammo)

# %%
Logistic_Model('Case2_Scenario3.csv').run()
# Out:
# Time: 0.0 Event: Init Ship NA Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 103.47713075742456 Event: Fuel Needed Ship CG_62 Ship Fuel Qty: 0 Ship Ammo Qty: 18 Resupply Ship T_AOE_6 Resupply Fuel Qty: 177000 Resupply Ammo Qty: 1800
# Time: 106.7777862135506 Event: Fuel Needed Ship DDG_89 Ship Fuel Qty: 0 Ship Ammo Qty: 26 Resupply Ship T_AKE_4 Resupply Fuel Qty: 23450 Resupply Ammo Qty: 6000
# Time: 108.66734125586899 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 109.39663576987684 Event: Resupply Under Way Ship CG_62 Ship Fuel Qty: 3758 Ship Ammo Qty: 18 Resupply Ship T_AOE_6 Resupply Fuel Qty: 173242 Resupply Ammo Qty: 1782
# Time: 109.66734125586899 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 110.66734125586899 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 110.68123113067149 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 111.47817894972437 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 111.66734125586899 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 111.68123113067149 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 112.47817894972437 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 112.66734125586899 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 112.68123113067149 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 113.16979510080819 Event: Patrolling Ship CG_62 Ship Fuel Qty: 3758 Ship Ammo Qty: 18 Resupply Ship T_AOE_6 Resupply Fuel Qty: 173242 Resupply Ammo Qty: 1782
# Time: 113.47817894972437 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 113.66734125586899 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 113.68123113067149 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 114.47817894972437 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 114.66734125586899 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 114.68123113067149 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 115.47817894972437 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 115.66734125586899 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 115.68123113067149 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 116.47817894972437 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 116.54224701951473 Event: Resupply Under Way Ship DDG_89 Ship Fuel Qty: 2629 Ship Ammo Qty: 26 Resupply Ship T_AKE_4 Resupply Fuel Qty: 20821 Resupply Ammo Qty: 5974
# Time: 116.66734125586899 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 116.68123113067149 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 117.47817894972437 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 117.66734125586899 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 117.68123113067149 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 118.47817894972437 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 118.66734125586899 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 118.68123113067149 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 119.32724018368789 Event: Patrolling Ship DDG_89 Ship Fuel Qty: 2629 Ship Ammo Qty: 26 Resupply Ship T_AKE_4 Resupply Fuel Qty: 20821 Resupply Ammo Qty: 5974
# Time: 119.47817894972437 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 119.66734125586899 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 119.68123113067149 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 120.47817894972437 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 120.66734125586899 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 120.68123113067149 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 121.47817894972437 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 121.66734125586899 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 121.68123113067149 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 122.47817894972437 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 122.66734125586899 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 122.68123113067149 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 123.47817894972437 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 123.66734125586899 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 123.68123113067149 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 124.47817894972437 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 124.66734125586899 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 124.68123113067149 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 124.81560439162995 Event: !!Resupply Unavailable!! Ship DDG_85 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 125.47817894972437 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 125.66734125586899 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 125.68123113067149 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 125.81560439162995 Event: !!Resupply Unavailable!! Ship DDG_85 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 126.47817894972437 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 126.66734125586899 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 126.68123113067149 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 126.81560439162995 Event: !!Resupply Unavailable!! Ship DDG_85 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 127.47817894972437 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 127.66734125586899 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 127.68123113067149 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 127.81560439162995 Event: !!Resupply Unavailable!! Ship DDG_85 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 128.47817894972437 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 128.667341255869 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 128.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 128.81560439162996 Event: !!Resupply Unavailable!! Ship DDG_85 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 129.47817894972437 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 129.667341255869 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 129.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 129.81560439162996 Event: !!Resupply Unavailable!! Ship DDG_85 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 130.47817894972437 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 130.667341255869 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 130.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 130.81560439162996 Event: !!Resupply Unavailable!! Ship DDG_85 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 131.47817894972437 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 131.667341255869 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 131.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 131.81560439162996 Event: !!Resupply Unavailable!! Ship DDG_85 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 132.47817894972437 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 132.667341255869 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 132.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 132.81560439162996 Event: !!Resupply Unavailable!! Ship DDG_85 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 133.47817894972437 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 133.667341255869 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 133.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 133.81560439162996 Event: !!Resupply Unavailable!! Ship DDG_85 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 134.47817894972437 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 134.667341255869 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 134.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 134.81560439162996 Event: !!Resupply Unavailable!! Ship DDG_85 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 135.47817894972437 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 135.667341255869 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 135.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 135.81560439162996 Event: !!Resupply Unavailable!! Ship DDG_85 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 136.47817894972437 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 136.667341255869 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 136.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 136.81560439162996 Event: !!Resupply Unavailable!! Ship DDG_85 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 137.1142586844532 Event: Resupply Available Ship NA Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship T_AKE_4 Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 137.47817894972437 Event: Fuel Needed Ship DDG_63 Ship Fuel Qty: 0 Ship Ammo Qty: 26 Resupply Ship T_AKE_4 Resupply Fuel Qty: 20821 Resupply Ammo Qty: 5974
# Time: 137.667341255869 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 137.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 137.81560439162996 Event: !!Resupply Unavailable!! Ship DDG_85 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 138.667341255869 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 138.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 138.81560439162996 Event: !!Resupply Unavailable!! Ship DDG_85 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 139.667341255869 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 139.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 139.81560439162996 Event: !!Resupply Unavailable!! Ship DDG_85 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 140.667341255869 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 140.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 140.81560439162996 Event: !!Resupply Unavailable!! Ship DDG_85 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 141.667341255869 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 141.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 141.76926568523763 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 141.81560439162996 Event: !!Resupply Unavailable!! Ship DDG_85 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 142.667341255869 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 142.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 142.76926568523763 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 142.81560439162996 Event: !!Resupply Unavailable!! Ship DDG_85 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 143.667341255869 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 143.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 143.76926568523763 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 143.81560439162996 Event: !!Resupply Unavailable!! Ship DDG_85 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 144.667341255869 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 144.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 144.76926568523763 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 144.81560439162996 Event: !!Resupply Unavailable!! Ship DDG_85 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 145.667341255869 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 145.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 145.76926568523763 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 145.81560439162996 Event: !!Resupply Unavailable!! Ship DDG_85 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 146.667341255869 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 146.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 146.76926568523763 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 146.81560439162996 Event: !!Resupply Unavailable!! Ship DDG_85 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 147.667341255869 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 147.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 147.76926568523763 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 147.81560439162996 Event: !!Resupply Unavailable!! Ship DDG_85 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 148.667341255869 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 148.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 148.76926568523763 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 148.81560439162996 Event: !!Resupply Unavailable!! Ship DDG_85 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 149.667341255869 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 149.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 149.76926568523763 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 149.81560439162996 Event: !!Resupply Unavailable!! Ship DDG_85 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 150.667341255869 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 150.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 150.76926568523763 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 150.81560439162996 Event: !!Resupply Unavailable!! Ship DDG_85 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 151.667341255869 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 151.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 151.76926568523763 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 151.81560439162996 Event: !!Resupply Unavailable!! Ship DDG_85 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 152.667341255869 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 152.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 152.76926568523763 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 152.81560439162996 Event: !!Resupply Unavailable!! Ship DDG_85 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 153.50866869738473 Event: Resupply Available Ship NA Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship T_AOE_6 Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 153.667341255869 Event: Fuel Needed Ship DDG_62 Ship Fuel Qty: 0 Ship Ammo Qty: 26 Resupply Ship T_AOE_6 Resupply Fuel Qty: 173242 Resupply Ammo Qty: 1782
# Time: 153.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 153.76926568523763 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 153.81560439162996 Event: !!Resupply Unavailable!! Ship DDG_85 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 154.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 154.76926568523763 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 154.81560439162996 Event: !!Resupply Unavailable!! Ship DDG_85 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 155.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 155.76926568523763 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 155.81560439162996 Event: !!Resupply Unavailable!! Ship DDG_85 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 156.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 156.76926568523763 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 156.81560439162996 Event: !!Resupply Unavailable!! Ship DDG_85 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 157.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 157.76926568523763 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 157.81560439162996 Event: !!Resupply Unavailable!! Ship DDG_85 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 158.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 158.76926568523763 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 158.81560439162996 Event: !!Resupply Unavailable!! Ship DDG_85 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 159.06109099607582 Event: Resupply Under Way Ship DDG_63 Ship Fuel Qty: 2629 Ship Ammo Qty: 26 Resupply Ship T_AKE_4 Resupply Fuel Qty: 18192 Resupply Ammo Qty: 5948
# Time: 159.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 159.76926568523763 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 159.81560439162996 Event: !!Resupply Unavailable!! Ship DDG_85 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 160.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 160.76926568523763 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 160.81560439162996 Event: !!Resupply Unavailable!! Ship DDG_85 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 161.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 161.76926568523763 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 161.81560439162996 Event: !!Resupply Unavailable!! Ship DDG_85 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 162.03421692931255 Event: Patrolling Ship DDG_63 Ship Fuel Qty: 2629 Ship Ammo Qty: 26 Resupply Ship T_AKE_4 Resupply Fuel Qty: 18192 Resupply Ammo Qty: 5948
# Time: 162.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 162.76926568523763 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 162.81560439162996 Event: !!Resupply Unavailable!! Ship DDG_85 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 163.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 163.76926568523763 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 163.81560439162996 Event: !!Resupply Unavailable!! Ship DDG_85 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 164.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 164.76926568523763 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 164.81560439162996 Event: !!Resupply Unavailable!! Ship DDG_85 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 165.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 165.76926568523763 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 165.81560439162996 Event: !!Resupply Unavailable!! Ship DDG_85 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 166.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 166.76926568523763 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 166.81560439162996 Event: !!Resupply Unavailable!! Ship DDG_85 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 167.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 167.76926568523763 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 167.81560439162996 Event: !!Resupply Unavailable!! Ship DDG_85 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 168.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 168.76926568523763 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 168.81560439162996 Event: !!Resupply Unavailable!! Ship DDG_85 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 169.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 169.689474962334 Event: Resupply Available Ship NA Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship T_AKE_4 Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 169.76926568523763 Event: !!Not big enough!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 169.81560439162996 Event: Fuel Needed Ship DDG_85 Ship Fuel Qty: 0 Ship Ammo Qty: 26 Resupply Ship T_AKE_4 Resupply Fuel Qty: 18192 Resupply Ammo Qty: 5948
# Time: 170.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 170.76926568523763 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 171.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 171.76926568523763 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 172.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 172.76926568523763 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 173.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 173.76926568523763 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 174.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 174.76926568523763 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 175.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 175.76926568523763 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 176.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 176.76926568523763 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 177.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 177.76926568523763 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 178.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 178.76926568523763 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 179.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 179.76926568523763 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 180.652729302108 Event: !!Resupply Unavailable!! Ship DDG_89 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 180.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 180.76926568523763 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 181.652729302108 Event: !!Resupply Unavailable!! Ship DDG_89 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 181.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 181.76926568523763 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 182.652729302108 Event: !!Resupply Unavailable!! Ship DDG_89 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 182.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 182.76926568523763 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 183.652729302108 Event: !!Resupply Unavailable!! Ship DDG_89 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 183.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 183.76926568523763 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 184.652729302108 Event: !!Resupply Unavailable!! Ship DDG_89 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 184.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 184.76926568523763 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 185.652729302108 Event: !!Resupply Unavailable!! Ship DDG_89 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 185.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 185.76926568523763 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 186.652729302108 Event: !!Resupply Unavailable!! Ship DDG_89 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 186.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 186.76926568523763 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 187.652729302108 Event: !!Resupply Unavailable!! Ship DDG_89 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 187.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 187.76926568523763 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 188.652729302108 Event: !!Resupply Unavailable!! Ship DDG_89 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 188.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 188.76926568523763 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 189.652729302108 Event: !!Resupply Unavailable!! Ship DDG_89 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 189.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 189.76926568523763 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 190.652729302108 Event: !!Resupply Unavailable!! Ship DDG_89 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 190.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 190.76926568523763 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 191.652729302108 Event: !!Resupply Unavailable!! Ship DDG_89 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 191.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 191.76926568523763 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 192.652729302108 Event: !!Resupply Unavailable!! Ship DDG_89 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 192.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 192.76926568523763 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 193.652729302108 Event: !!Resupply Unavailable!! Ship DDG_89 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 193.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 193.76926568523763 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 194.652729302108 Event: !!Resupply Unavailable!! Ship DDG_89 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 194.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 194.76926568523763 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 195.652729302108 Event: !!Resupply Unavailable!! Ship DDG_89 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 195.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 195.76926568523763 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 196.652729302108 Event: !!Resupply Unavailable!! Ship DDG_89 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 196.6812311306715 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 196.76926568523763 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 197.652729302108 Event: !!Resupply Unavailable!! Ship DDG_89 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# ...
# Time: 1408.3192522025165 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1409.005822095562 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1409.0541837817632 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1409.3192522025165 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1410.005822095562 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1410.0541837817632 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1410.3192522025165 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1411.005822095562 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1411.0541837817632 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1411.3192522025165 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1412.005822095562 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1412.0541837817632 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1412.3192522025165 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1413.005822095562 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1413.0541837817632 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1413.3192522025165 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1414.005822095562 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1414.0541837817632 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1414.3192522025165 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1415.005822095562 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1415.0541837817632 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1415.3192522025165 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1416.005822095562 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1416.0541837817632 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1416.3192522025165 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1417.005822095562 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1417.0541837817632 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1417.3192522025165 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1418.005822095562 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1418.0541837817632 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1418.3192522025165 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1419.005822095562 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1419.0541837817632 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1419.3192522025165 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1420.005822095562 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1420.0541837817632 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1420.3192522025165 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1421.005822095562 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1421.0541837817632 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1421.3192522025165 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1421.4112577504643 Event: Resupply Under Way Ship DDG_62 Ship Fuel Qty: 2629 Ship Ammo Qty: 26 Resupply Ship T_AKE_4 Resupply Fuel Qty: 18192 Resupply Ammo Qty: 5948
# Time: 1422.005822095562 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1422.0541837817632 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1422.3192522025165 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1423.005822095562 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1423.0541837817632 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1423.3192522025165 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1424.005822095562 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1424.0541837817632 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1424.3192522025165 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1425.005822095562 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1425.0541837817632 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1425.3192522025165 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1425.9841341774754 Event: Patrolling Ship DDG_62 Ship Fuel Qty: 2629 Ship Ammo Qty: 26 Resupply Ship T_AKE_4 Resupply Fuel Qty: 18192 Resupply Ammo Qty: 5948
# Time: 1426.005822095562 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1426.0541837817632 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1426.3192522025165 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1427.005822095562 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1427.0541837817632 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1427.3192522025165 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1428.005822095562 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1428.0541837817632 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1428.3192522025165 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1429.005822095562 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1429.0541837817632 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1429.3192522025165 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1430.005822095562 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1430.0541837817632 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1430.3192522025165 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1431.005822095562 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1431.0541837817632 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1431.3192522025165 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1432.005822095562 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1432.0541837817632 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1432.3192522025165 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1433.005822095562 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1433.0541837817632 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1433.3192522025165 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1434.005822095562 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1434.0541837817632 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1434.3192522025165 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1435.005822095562 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1435.0541837817632 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1435.3192522025165 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1436.005822095562 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1436.0541837817632 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1436.3192522025165 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1437.005822095562 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1437.0541837817632 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1437.3192522025165 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1438.005822095562 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1438.0541837817632 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1438.3192522025165 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1439.005822095562 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1439.0541837817632 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1439.3192522025165 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA

# %%
335*8.5
# Out:
# 2847.5
