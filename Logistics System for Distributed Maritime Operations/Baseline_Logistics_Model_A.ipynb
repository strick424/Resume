# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from shapely import geometry
import random
import math
# %matplotlib inline

# %%
data = pd.read_csv('boundingbox.csv')
data['lon direction']=data['\ufefflon direction'] 
del data['\ufefflon direction']

# %%
brunei = [5.033182, 115.086013]
phillipines = [14.790988, 120.242715]
singapore = [1.461519, 103.831384]
vietnam = [11.901643, 109.170094]
bases = [brunei,phillipines,singapore,vietnam]

# %%
def degMinSecToDecimal(deg, mn, sec):
    """ convert (degrees,minutes,seconds) to decimal-degrees """
    decimal = deg + (mn/60.0) + (sec/3600.0)
    return decimal

def calc_distance(lat1, lon1, lat2, lon2):
    '''This function calculates the distance between two coordinates. It takes 2 lat/lon pairs of coordinates in 
    decimal representation and first converts them to radians. The coordinates must already be in there decimal 
    representation to be used as inputs. It then calculates the distance between the two coordinates using the
    great circle distance equation from the reference. From there it converts that distance from radians back to nm.'''
    rlat1 = deg2rad(lat1) #converts lat/longs from degrees to radians
    rlon1 = deg2rad(lon1)
    rlat2 = deg2rad(lat2)
    rlon2 = deg2rad(lon2)
    d = math.acos(math.sin(rlat1) * math.sin(rlat2) + math.cos(rlat1) * math.cos(rlat2) * math.cos(rlon1 - rlon2))
    # calculates distance between two points in radians. formula provided in reference
    nm = rad2nm(d) # this converts the distance from radians to nm
    return nm
#end of calc_distance

def rad2nm (radians):
    '''This function converts a distance in radians into nautical miles. It will take one input in radians.'''
    nm = ((180 * 60) / math.pi) * radians
    return nm #returns the distance in nm
#end of rad2nm


def deg2rad (degrees):
    '''This function will convert a coordinate location in decimal representation in degrees to its value
    in radians. The input is the decimal degree location of a single coordinate.'''
    radians = degrees * ((math.pi)/180)
    return radians #returns the value in radians
# end of deg2rad

# %%
boxpoints =[]
for index,row in data.iterrows():
    lat = degMinSecToDecimal(row['lat degrees '],row['lat minutes '],row['lat seconds'])
    lon = degMinSecToDecimal(row['lon degrees'],row['lon minutes'],row['lon seconds'])
    if row['lat direction']=='S':
        lat = -lat
    if row['lon direction']=='W':
        lon= -lon
    boxpoints.append([lat,lon])
    
poly = geometry.Polygon(boxpoints)
#poly.wkt

# %%
def get_random_point_in_polygon(poly):
    (minx, miny, maxx, maxy) = poly.bounds
    test = False
    while test == False:
        p = geometry.Point(random.uniform(minx, maxx), random.uniform(miny, maxy))
        if poly.contains(p):
            #print(p)
            test = True
            return p

# %%
def initial_resupply_locations(rs_ship,rs_ship_dict,maxdistance):
    test=False
    while test == False:
        point = get_random_point_in_polygon(poly)
        loc = calc_distance(point.x,point.y,rs_ship_dict[rs_ship][5][0],rs_ship_dict[rs_ship][5][1])
        if loc <= maxdistance:
            test=True
            goodpoint=point
    return goodpoint

# %%
def resupply_back_out(rs,rs_ship_dict,maxdistance,speed):
    test=False
    while test == False:
        point = get_random_point_in_polygon(poly)
        distance = calc_distance(point.x,point.y,rs_ship_dict[rs][5][0],rs_ship_dict[rs][5][1])
        if distance <= maxdistance:
            test=True
            goodpoint=point
            time=distance/speed
    return time,goodpoint

# %%
def patrol_needs_fuel(ship,ship_dict,rs_ship_dict,avail_rs_list,speed):
    ship_point = ship_dict[ship][4]
    distance_list = []
    for rs_ship in avail_rs_list:
        if rs_ship_dict[rs_ship][0]>= ship_dict[ship][2]:
            rs_loc = rs_ship_dict[rs_ship][4]
            distance_list.append([rs_ship,calc_distance(ship_point.x,ship_point.y,rs_loc.x,rs_loc.y)])
    rs,dist = find_min_distance(distance_list)
    time = dist/speed
    return rs,time

# %%
def find_distancelist(ship,ship_dict,rs_ship_dict,avail_rs_list):
    ship_point = ship_dict[ship][4]
    distance_list = []
    fuel_need = ship_dict[ship][2]-ship_dict[ship][0]
    for rs_ship in avail_rs_list:
        if rs_ship_dict[rs_ship][0] >= fuel_need:
            rs_loc = rs_ship_dict[rs_ship][4]
            distance_list.append([rs_ship,calc_distance(ship_point.x,ship_point.y,rs_loc.x,rs_loc.y)])
    return distance_list

# %%
def find_min_distance(distancelist,speed):
    min_distance = 1000000
    #min_ship = line[0]
    for line in distancelist:
        if line[1] < min_distance:
            min_distance = line[1]
            min_ship = line[0]
            time = min_distance/speed
    return min_ship,time,min_distance

# %%
def patrol_back_out(patrol_ship,rs_ship,rs_ship_dict,maxdistance,speed):
    test=False
    while test == False:
        point = get_random_point_in_polygon(poly)
        distance = calc_distance(point.x,point.y,rs_ship_dict[rs_ship][4].x,rs_ship_dict[rs_ship][4].y)
        if distance <= maxdistance:
            test=True
            goodpoint=point
            time = distance/speed
    return goodpoint,time

# %%
def resupply_ship_needs_fuel(rs,rs_ship_dict,speed):
    point= rs_ship_dict[rs][4]
    distance = calc_distance(point.x,point.y,rs_ship_dict[rs][5][0],rs_ship_dict[rs][5][1])
    time = distance/speed
    return time

# %%
point=get_random_point_in_polygon(poly)
#print(point)

# %%
from queue import PriorityQueue
import abc

class SimpleKit:
    """
    To create a SimpleKit model:
        Your model class must be a subclass of SimpleKit.
        Your constructor (__init__()) must call SimpleKit.__init__(self).
        You must override the abstract init() method to start your model.
    Note:
        Your model cannot implement methods named run(), schedule(), or halt().
    """
    __metaclass__ = abc.ABCMeta

    def __init__(self):
        """Initialize a pending events list and set model_time to 0."""
        self.event_list = PriorityQueue()
        self.model_time = 0.0
    
    @abc.abstractmethod
    def init(self):
        """This abstract method must be overridden in your model class."""

    def run(self):
        """Execute the model logic."""
        self.init()
        while not self.event_list.empty():
            event_notice = self.event_list.get()
            self.model_time = event_notice[0]
            event_notice[1](*event_notice[2:])

    def schedule(self, event, delay, *args):
        """Add an event to the pending events.

        Args:
            event: The name of the event method to be scheduled.
            delay: The amount of model time by which to delay the execution.
            args: (optional) Any arguments required by the event.
        """
        if delay < 0:
            raise RuntimeError('Negative delay is not allowed.')
        event_notice = [delay + self.model_time, event] + list(args)
        self.event_list.put(event_notice)
        print(self.event_list.values)
    
    def halt(self):
        """Terminate a simulation run by clearing the pending events list."""
        while not self.event_list.empty():
            self.event_list.get()

# %%
from simplekit import SimpleKit
import numpy as numpy
import math
import csv

class Logistic_Model(SimpleKit):
    """Implementation of a Maritime Logistics System for refueling ."""

    def __init__(self, outfile):
        """Construct an instance of the M/M/k."""
        SimpleKit.__init__(self)        
        
        #initialize all values of self for the system
        #Demand values
        self.CSG_cap_fuel = 17000+2200*3+2100
        self.DDG_cap_fuel = 2629
        self.CG_cap_fuel = 3758
        #self.CVN_cap_ammo = 0
        self.CSG_cap_ammo = 268
        self.DDG_cap_ammo = 26
        self.CG_cap_ammo = 18
        
        #Resupply Ship Values
            #FCS:
        self.TAOE_cap_fuel = 177000 #barrels
        self.TAOE_cap_ammo = 1800 #tons
            
            #Lewis and Clark:
        self.TAKE_cap_fuel = 23450 #barrels
        self.TAKE_cap_ammo = 6000 #tons 
            
            #CLS
        self.CLS5000_cap_fuel = 2900
        self.CLS5000_cap_ammo = 500
        
        #self.speed = 18 #knots
        #create and output file based on the given outfile name
        b = open(outfile, 'w', newline='') 
        fieldnames = ['Model_Time', 'Event', "Ship", "Ship Fuel Qty",'Ship Ammo Qty',
                      "Resupply Ship", "Resupply Fuel Qty",'Resupply Ammo Qty']
        self.outcsvfile = csv.DictWriter(b, fieldnames=fieldnames)
        self.outcsvfile.writeheader()
     
    
    def init(self):
        """Initialize all state variables, schedule first demand."""
        
        #Demand ships
        self.ship_list = ['CSG', #carrier
                          'DDG_62', 'DDG_63', 'DDG_85', 'DDG_89', #destroyers
                          'CG_62', 'CG_67'] #cruisers
        
                         #'ship'  : [fuel level,        ammo level,        fuel capacity,     ammo capacity     , location(tuple)]     
        self.ship_dict = {'CSG': [self.CSG_cap_fuel, self.CSG_cap_ammo, self.CSG_cap_fuel, self.CSG_cap_ammo, get_random_point_in_polygon(poly)], 
                          #'DDG_52': [self.DDG_cap_fuel, self.DDG_cap_ammo, self.DDG_cap_fuel, self.DDG_cap_ammo, get_random_point_in_polygon(poly)],
                          #'DDG_54': [self.DDG_cap_fuel, self.DDG_cap_ammo, self.DDG_cap_fuel, self.DDG_cap_ammo, get_random_point_in_polygon(poly)],
                          #'DDG_56': [self.DDG_cap_fuel, self.DDG_cap_ammo, self.DDG_cap_fuel, self.DDG_cap_ammo, get_random_point_in_polygon(poly)],
                          'DDG_62': [self.DDG_cap_fuel, self.DDG_cap_ammo, self.DDG_cap_fuel, self.DDG_cap_ammo, get_random_point_in_polygon(poly)],
                          'DDG_63': [self.DDG_cap_fuel, self.DDG_cap_ammo, self.DDG_cap_fuel, self.DDG_cap_ammo, get_random_point_in_polygon(poly)],
                          'DDG_85': [self.DDG_cap_fuel, self.DDG_cap_ammo, self.DDG_cap_fuel, self.DDG_cap_ammo, get_random_point_in_polygon(poly)],
                          'DDG_89': [self.DDG_cap_fuel, self.DDG_cap_ammo, self.DDG_cap_fuel, self.DDG_cap_ammo, get_random_point_in_polygon(poly)],
                          #'CG_54':  [self.CG_cap_fuel,  self.CG_cap_ammo,  self.CG_cap_fuel,  self.CG_cap_ammo, get_random_point_in_polygon(poly)],
                          'CG_62':  [self.CG_cap_fuel,  self.CG_cap_ammo,  self.CG_cap_fuel,  self.CG_cap_ammo, get_random_point_in_polygon(poly)],
                          'CG_67':  [self.CG_cap_fuel,  self.CG_cap_ammo,  self.CG_cap_fuel,  self.CG_cap_ammo, get_random_point_in_polygon(poly)]} 
        
        #Resupply ships:
        self.rs_ship_list = ['T_AOE_6', 'T_AKE_4']#, 'T_AKE_3'] 
                             #'CLS_1','CLS_2','CLS_3','CLS_4'] 'T_AOE_8', 
        
                            #'ship'    : [fuel level,        ammo level,        fuel capacity,     ammo capacity]
        self.rs_ship_dict = {'T_AOE_6': [self.TAOE_cap_fuel, self.TAOE_cap_ammo, self.TAOE_cap_fuel, self.TAOE_cap_ammo, [0,0],brunei],
                             #'T_AOE_8': [self.TAOE_cap_fuel, self.TAOE_cap_ammo, self.TAOE_cap_fuel, self.TAOE_cap_ammo, [0,0],phillipines],
                             #'T_AKE_3': [self.TAKE_cap_fuel, self.TAKE_cap_ammo, self.TAKE_cap_fuel, self.TAKE_cap_ammo, [0,0],brunei]}#,
                             'T_AKE_4': [self.TAKE_cap_fuel, self.TAKE_cap_ammo, self.TAKE_cap_fuel, self.TAKE_cap_ammo, [0,0],vietnam]}
                             #'CLS_1': [self.CLS5000_cap_fuel, self.CLS5000_cap_ammo, self.CLS5000_cap_fuel, self.CLS5000_cap_ammo, [0,0],vietnam],
                             #'CLS_2': [self.CLS5000_cap_fuel, self.CLS5000_cap_ammo, self.CLS5000_cap_fuel, self.CLS5000_cap_ammo, [0,0],phillipines],
                             #'CLS_3': [self.CLS5000_cap_fuel, self.CLS5000_cap_ammo, self.CLS5000_cap_fuel, self.CLS5000_cap_ammo, [0,0],brunei],
                             #'CLS_4': [self.CLS5000_cap_fuel, self.CLS5000_cap_ammo, self.CLS5000_cap_fuel, self.CLS5000_cap_ammo, [0,0],singapore]
       
        #resupply ships available to resupply
        self.avail_rs_list = ['T_AOE_6','T_AKE_4']#, 'T_AKE_3']'T_AOE_8',
                             #'CLS_1','CLS_2','CLS_3','CLS_4'] 
        
        self.schedule(self.halt, 24*60)  #run the model for 15 days
        
        for ship in self.ship_list: #schedule when all ships run out of fuel and where they will be located 
            self.schedule(self.demand, random.uniform(96,144), ship)
        
        for rs_ship in self.rs_ship_list:
            self.rs_ship_dict[rs_ship][4] = initial_resupply_locations(rs_ship,self.rs_ship_dict,300)

        self.dumpState("Init", 'NA', 'NA', 'NA', 'NA','NA','NA')
        
    def demand(self,ship):
        """Check to determine if any ships need fuel/ammo"""
        self.ship_dict[ship][0]=0
        
        if len(self.avail_rs_list) == 0:
            self.schedule(self.demand, 1, ship) #no resupply ship is available, check back in an hour
            self.dumpState('!!Resupply Unavailable!!',ship,'NA','NA','NA','NA','NA') #surface ship can not be resupplied at the time
        else:
            dl = find_distancelist(ship,self.ship_dict,self.rs_ship_dict,self.avail_rs_list)
            if len(dl)== 0:
                self.schedule(self.demand, 1, ship) #no resupply ship is available, check back in an hour
                self.dumpState('!!Not big enough!!',ship,'NA','NA','NA','NA','NA')#surface ship can not be resupplied at the time
            else:
                rs,time,dist=find_min_distance(dl,18)
                self.avail_rs_list.remove(rs)
                self.schedule(self.resupply,time,ship,rs,dist)
                self.dumpState('Fuel Needed',ship,self.ship_dict[ship][0],self.ship_dict[ship][1],
                               rs,self.rs_ship_dict[rs][0],self.rs_ship_dict[rs][1])
        
    def resupply(self, ship, resupply,distance):
        """Subtract fuel from resupply ship, reset fuel for surface ship, schedule both ships to go on patrol"""
        survival = random.uniform(0,1)
        if survival > 0.999:
            self.schedule(self.demand,1,ship)
            self.rs_ship_list.remove(resupply)
            self.dumpState('Resupply ship did not survive!!!!',ship,'NA','NA',resupply,'NA','NA')
        else:
            self.schedule(self.patrol, numpy.random.normal(4, 1), ship, resupply)
            self.rs_ship_dict[resupply][1] -= self.ship_dict[ship][3] #subtract ammo from resupply
            self.rs_ship_dict[resupply][0] = self.rs_ship_dict[resupply][0] - self.ship_dict[ship][2] #subtract the fuel transferred from resupply ship
            self.ship_dict[ship][0] = self.ship_dict[ship][2] #reset the fuel guage for ship
            self.ship_dict[ship][1] = self.ship_dict[ship][3] #reset ammo for ship
            self.dumpState("Resupply Under Way", ship, self.ship_dict[ship][0],self.ship_dict[ship][1],
                           resupply, self.rs_ship_dict[resupply][0], self.rs_ship_dict[resupply][1]) 
    
    
    def patrol(self, ship, resupply):
        """Schedule when the ship needs fuel and it's location at that time, check to see if the resupply ship needs fuel"""
        self.ship_dict[ship][4],time = patrol_back_out(ship,resupply,self.rs_ship_dict,2000,18)
        
        self.schedule(self.demand, (random.uniform(96,144))+time, ship) #Schedule when the ship runs out of fuel!!! dictionary value based on avearge fuel rates 
        
        
        if (self.rs_ship_dict[resupply][0] <= 0.25*self.rs_ship_dict[resupply][2]) or (self.rs_ship_dict[resupply][1] <= 268): #check if the resupply ship needs fuel
            time = resupply_ship_needs_fuel(resupply,self.rs_ship_dict,20)
            self.schedule(self.resupply_resupply, time, resupply) #schedule a time to resupply the resupply ship
            self.dumpState("Return to Base", 'NA', 'NA','NA', 
                           resupply, self.rs_ship_dict[resupply][0], self.rs_ship_dict[resupply][1])#,"resupplying")
            self.dumpState("Patrolling", ship, self.ship_dict[ship][0],self.ship_dict[ship][1],
                           resupply, self.rs_ship_dict[resupply][0], self.rs_ship_dict[resupply][1])
        else:
            self.avail_rs_list.append(resupply)
            self.dumpState("Patrolling", ship, self.ship_dict[ship][0],self.ship_dict[ship][1],
                           resupply, self.rs_ship_dict[resupply][0], self.rs_ship_dict[resupply][1])    
    
    
    def resupply_resupply(self, resupply):
        """Reset the resupply levels of the resupply ships, generate a location for it to travel to, append it to the available list"""
        self.rs_ship_dict[resupply][0] = self.rs_ship_dict[resupply][2] #resupply ship is topped back off
        self.rs_ship_dict[resupply][1] = self.rs_ship_dict[resupply][3]
        time,self.rs_ship_dict[resupply][4] = resupply_back_out(resupply,self.rs_ship_dict,300,20)
        self.schedule(self.resupply_available,time,resupply)
        self.dumpState("Resupplying Resupply", "NA", "NA",'NA',
                       resupply, self.rs_ship_dict[resupply][0], self.rs_ship_dict[resupply][1])
    
    def resupply_available(self,resupply):
        self.avail_rs_list.append(resupply)
        self.dumpState('Resupply Available','NA','NA','NA',resupply,'NA','NA')
        
    def dumpState(self, event, ship, ship_fuel, ship_ammo, resupply, resupply_fuel,resupply_ammo): #this state prints all values to the .csv file
        """Dump of the current state of the model."""
        self.outcsvfile.writerow({'Model_Time': float(self.model_time), 'Event': event, 
                                  'Ship':ship, 'Ship Fuel Qty': ship_fuel,'Ship Ammo Qty': ship_ammo, 
                                  'Resupply Ship': resupply,  'Resupply Fuel Qty': resupply_fuel,
                                  'Resupply Ammo Qty':resupply_ammo}) 
        print("Time:", self.model_time, "Event:", event,'Ship', ship, "Ship Fuel Qty:", ship_fuel,'Ship Ammo Qty:',ship_ammo,
              'Resupply Ship', resupply, "Resupply Fuel Qty:", resupply_fuel, 'Resupply Ammo Qty:',resupply_ammo)

# %%
Logistic_Model('Case1_Scenario3.csv').run()
# Out:
# Time: 0.0 Event: Init Ship NA Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 100.20276709788956 Event: Fuel Needed Ship DDG_62 Ship Fuel Qty: 0 Ship Ammo Qty: 26 Resupply Ship T_AKE_4 Resupply Fuel Qty: 23450 Resupply Ammo Qty: 6000
# Time: 105.6598372624386 Event: Fuel Needed Ship CG_67 Ship Fuel Qty: 0 Ship Ammo Qty: 18 Resupply Ship T_AOE_6 Resupply Fuel Qty: 177000 Resupply Ammo Qty: 1800
# Time: 108.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 109.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 110.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 111.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 112.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 112.62216517604652 Event: !!Resupply Unavailable!! Ship DDG_89 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 113.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 113.62216517604652 Event: !!Resupply Unavailable!! Ship DDG_89 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 114.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 114.62216517604652 Event: !!Resupply Unavailable!! Ship DDG_89 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 115.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 115.62216517604652 Event: !!Resupply Unavailable!! Ship DDG_89 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 116.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 116.62216517604652 Event: !!Resupply Unavailable!! Ship DDG_89 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 117.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 117.62216517604652 Event: !!Resupply Unavailable!! Ship DDG_89 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 118.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 118.62216517604652 Event: !!Resupply Unavailable!! Ship DDG_89 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 119.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 119.62216517604652 Event: !!Resupply Unavailable!! Ship DDG_89 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 120.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 120.62216517604652 Event: !!Resupply Unavailable!! Ship DDG_89 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 121.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 121.62216517604652 Event: !!Resupply Unavailable!! Ship DDG_89 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 122.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 122.62216517604652 Event: !!Resupply Unavailable!! Ship DDG_89 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 122.95295140641373 Event: Resupply Under Way Ship DDG_62 Ship Fuel Qty: 2629 Ship Ammo Qty: 26 Resupply Ship T_AKE_4 Resupply Fuel Qty: 20821 Resupply Ammo Qty: 5974
# Time: 123.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 123.62216517604652 Event: !!Resupply Unavailable!! Ship DDG_89 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 124.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 124.62216517604652 Event: !!Resupply Unavailable!! Ship DDG_89 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 125.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 125.62216517604652 Event: !!Resupply Unavailable!! Ship DDG_89 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 126.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 126.62216517604652 Event: !!Resupply Unavailable!! Ship DDG_89 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 127.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 127.62216517604652 Event: !!Resupply Unavailable!! Ship DDG_89 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 128.16515599077673 Event: Patrolling Ship DDG_62 Ship Fuel Qty: 2629 Ship Ammo Qty: 26 Resupply Ship T_AKE_4 Resupply Fuel Qty: 20821 Resupply Ammo Qty: 5974
# Time: 128.3685956144032 Event: !!Not big enough!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 128.6221651760465 Event: Fuel Needed Ship DDG_89 Ship Fuel Qty: 0 Ship Ammo Qty: 26 Resupply Ship T_AKE_4 Resupply Fuel Qty: 20821 Resupply Ammo Qty: 5974
# Time: 129.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 130.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 131.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 132.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 133.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 134.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 135.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 136.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 137.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 138.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 139.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 139.86476219815526 Event: Resupply Under Way Ship DDG_89 Ship Fuel Qty: 2629 Ship Ammo Qty: 26 Resupply Ship T_AKE_4 Resupply Fuel Qty: 18192 Resupply Ammo Qty: 5948
# Time: 140.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 141.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 142.0834840767301 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 142.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 143.0834840767301 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 143.1689808730112 Event: !!Resupply Unavailable!! Ship DDG_85 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 143.3037095701691 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 143.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 144.0834840767301 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 144.1689808730112 Event: !!Resupply Unavailable!! Ship DDG_85 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 144.3037095701691 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 144.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 145.0834840767301 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 145.1028015843847 Event: Patrolling Ship DDG_89 Ship Fuel Qty: 2629 Ship Ammo Qty: 26 Resupply Ship T_AKE_4 Resupply Fuel Qty: 18192 Resupply Ammo Qty: 5948
# Time: 145.1689808730112 Event: Fuel Needed Ship DDG_85 Ship Fuel Qty: 0 Ship Ammo Qty: 26 Resupply Ship T_AKE_4 Resupply Fuel Qty: 18192 Resupply Ammo Qty: 5948
# Time: 145.3037095701691 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 145.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 146.0834840767301 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 146.3037095701691 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 146.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 147.0834840767301 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 147.3037095701691 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 147.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 148.0834840767301 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 148.3037095701691 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 148.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 149.0834840767301 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 149.3037095701691 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 149.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 150.0834840767301 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 150.3037095701691 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 150.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 151.0834840767301 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 151.3037095701691 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 151.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 152.0834840767301 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 152.3037095701691 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 152.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 153.0834840767301 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 153.3037095701691 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 153.3170948715926 Event: Resupply Under Way Ship CG_67 Ship Fuel Qty: 3758 Ship Ammo Qty: 18 Resupply Ship T_AOE_6 Resupply Fuel Qty: 173242 Resupply Ammo Qty: 1782
# Time: 153.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 154.0834840767301 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 154.3037095701691 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 154.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 155.0834840767301 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 155.25801014044657 Event: Patrolling Ship CG_67 Ship Fuel Qty: 3758 Ship Ammo Qty: 18 Resupply Ship T_AOE_6 Resupply Fuel Qty: 173242 Resupply Ammo Qty: 1782
# Time: 155.3037095701691 Event: Fuel Needed Ship DDG_63 Ship Fuel Qty: 0 Ship Ammo Qty: 26 Resupply Ship T_AOE_6 Resupply Fuel Qty: 173242 Resupply Ammo Qty: 1782
# Time: 155.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 156.0834840767301 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 156.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 157.0834840767301 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 157.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 158.0834840767301 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 158.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 159.0834840767301 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 159.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 160.0834840767301 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 160.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 161.0834840767301 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 161.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 162.0834840767301 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 162.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 163.0834840767301 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 163.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 163.9501229741173 Event: Resupply Under Way Ship DDG_85 Ship Fuel Qty: 2629 Ship Ammo Qty: 26 Resupply Ship T_AKE_4 Resupply Fuel Qty: 15563 Resupply Ammo Qty: 5922
# Time: 164.0834840767301 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 164.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 165.0834840767301 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 165.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 166.0834840767301 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 166.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 167.0834840767301 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 167.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 167.6011220120241 Event: Patrolling Ship DDG_85 Ship Fuel Qty: 2629 Ship Ammo Qty: 26 Resupply Ship T_AKE_4 Resupply Fuel Qty: 15563 Resupply Ammo Qty: 5922
# Time: 168.0834840767301 Event: Fuel Needed Ship CG_62 Ship Fuel Qty: 0 Ship Ammo Qty: 18 Resupply Ship T_AKE_4 Resupply Fuel Qty: 15563 Resupply Ammo Qty: 5922
# Time: 168.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 169.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 170.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 171.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 172.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 173.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 174.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 175.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 176.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 177.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 178.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 179.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 180.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 181.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 182.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 183.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 184.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 185.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 186.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 187.0623413724809 Event: Resupply Under Way Ship CG_62 Ship Fuel Qty: 3758 Ship Ammo Qty: 18 Resupply Ship T_AKE_4 Resupply Fuel Qty: 11805 Resupply Ammo Qty: 5904
# Time: 187.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 188.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 189.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 190.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 191.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 192.3685956144032 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 192.44676978494468 Event: Patrolling Ship CG_62 Ship Fuel Qty: 3758 Ship Ammo Qty: 18 Resupply Ship T_AKE_4 Resupply Fuel Qty: 11805 Resupply Ammo Qty: 5904
# Time: 193.3685956144032 Event: !!Not big enough!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 194.3685956144032 Event: !!Not big enough!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 195.3685956144032 Event: !!Not big enough!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 196.3685956144032 Event: !!Not big enough!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 197.3685956144032 Event: !!Not big enough!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 197.52035253806116 Event: Resupply Under Way Ship DDG_63 Ship Fuel Qty: 2629 Ship Ammo Qty: 26 Resupply Ship T_AOE_6 Resupply Fuel Qty: 170613 Resupply Ammo Qty: 1756
# Time: 198.3685956144032 Event: !!Not big enough!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 199.3685956144032 Event: !!Not big enough!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 200.3685956144032 Event: !!Not big enough!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 200.56840482900387 Event: Patrolling Ship DDG_63 Ship Fuel Qty: 2629 Ship Ammo Qty: 26 Resupply Ship T_AOE_6 Resupply Fuel Qty: 170613 Resupply Ammo Qty: 1756
# Time: 201.3685956144032 Event: Fuel Needed Ship CSG Ship Fuel Qty: 0 Ship Ammo Qty: 268 Resupply Ship T_AOE_6 Resupply Fuel Qty: 170613 Resupply Ammo Qty: 1756
# Time: 220.89297463981504 Event: Resupply Under Way Ship CSG Ship Fuel Qty: 25700 Ship Ammo Qty: 268 Resupply Ship T_AOE_6 Resupply Fuel Qty: 144913 Resupply Ammo Qty: 1488
# Time: 224.9494063635562 Event: Patrolling Ship CSG Ship Fuel Qty: 25700 Ship Ammo Qty: 268 Resupply Ship T_AOE_6 Resupply Fuel Qty: 144913 Resupply Ammo Qty: 1488
# Time: 276.57154009109126 Event: Fuel Needed Ship DDG_89 Ship Fuel Qty: 0 Ship Ammo Qty: 26 Resupply Ship T_AKE_4 Resupply Fuel Qty: 11805 Resupply Ammo Qty: 5904
# Time: 287.2156754884006 Event: Resupply Under Way Ship DDG_89 Ship Fuel Qty: 2629 Ship Ammo Qty: 26 Resupply Ship T_AKE_4 Resupply Fuel Qty: 9176 Resupply Ammo Qty: 5878
# Time: 289.8112067125249 Event: Patrolling Ship DDG_89 Ship Fuel Qty: 2629 Ship Ammo Qty: 26 Resupply Ship T_AKE_4 Resupply Fuel Qty: 9176 Resupply Ammo Qty: 5878
# Time: 297.82013286905976 Event: Fuel Needed Ship DDG_62 Ship Fuel Qty: 0 Ship Ammo Qty: 26 Resupply Ship T_AOE_6 Resupply Fuel Qty: 144913 Resupply Ammo Qty: 1488
# Time: 306.3617355387339 Event: Fuel Needed Ship DDG_85 Ship Fuel Qty: 0 Ship Ammo Qty: 26 Resupply Ship T_AKE_4 Resupply Fuel Qty: 9176 Resupply Ammo Qty: 5878
# Time: 312.2069688706695 Event: Resupply Under Way Ship DDG_62 Ship Fuel Qty: 2629 Ship Ammo Qty: 26 Resupply Ship T_AOE_6 Resupply Fuel Qty: 142284 Resupply Ammo Qty: 1462
# Time: 315.192590699934 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 316.192590699934 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 316.2877638887468 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 317.1895935224238 Event: Patrolling Ship DDG_62 Ship Fuel Qty: 2629 Ship Ammo Qty: 26 Resupply Ship T_AOE_6 Resupply Fuel Qty: 142284 Resupply Ammo Qty: 1462
# Time: 317.192590699934 Event: Fuel Needed Ship CG_62 Ship Fuel Qty: 0 Ship Ammo Qty: 18 Resupply Ship T_AOE_6 Resupply Fuel Qty: 142284 Resupply Ammo Qty: 1462
# Time: 317.2877638887468 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 318.2877638887468 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 319.2877638887468 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 320.2877638887468 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 321.2877638887468 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 322.2877638887468 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 323.2877638887468 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 324.2877638887468 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 325.2877638887468 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 326.2877638887468 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 327.2877638887468 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 328.2877638887468 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 329.2877638887468 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 330.2877638887468 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 331.22309279506914 Event: Resupply Under Way Ship DDG_85 Ship Fuel Qty: 2629 Ship Ammo Qty: 26 Resupply Ship T_AKE_4 Resupply Fuel Qty: 6547 Resupply Ammo Qty: 5852
# Time: 331.2877638887468 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 332.2877638887468 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 333.2877638887468 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 334.2877638887468 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 335.2877638887468 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 336.2877638887468 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 337.032238518095 Event: Patrolling Ship DDG_85 Ship Fuel Qty: 2629 Ship Ammo Qty: 26 Resupply Ship T_AKE_4 Resupply Fuel Qty: 6547 Resupply Ammo Qty: 5852
# Time: 337.2877638887468 Event: Fuel Needed Ship CG_67 Ship Fuel Qty: 0 Ship Ammo Qty: 18 Resupply Ship T_AKE_4 Resupply Fuel Qty: 6547 Resupply Ammo Qty: 5852
# Time: 354.34323040709046 Event: Resupply Under Way Ship CG_62 Ship Fuel Qty: 3758 Ship Ammo Qty: 18 Resupply Ship T_AOE_6 Resupply Fuel Qty: 138526 Resupply Ammo Qty: 1444
# Time: 359.4620957637851 Event: Patrolling Ship CG_62 Ship Fuel Qty: 3758 Ship Ammo Qty: 18 Resupply Ship T_AOE_6 Resupply Fuel Qty: 138526 Resupply Ammo Qty: 1444
# Time: 359.5000241127242 Event: Resupply Under Way Ship CG_67 Ship Fuel Qty: 3758 Ship Ammo Qty: 18 Resupply Ship T_AKE_4 Resupply Fuel Qty: 2789 Resupply Ammo Qty: 5834
# Time: 363.54930051755855 Event: Return to Base Ship NA Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship T_AKE_4 Resupply Fuel Qty: 2789 Resupply Ammo Qty: 5834
# Time: 363.54930051755855 Event: Patrolling Ship CG_67 Ship Fuel Qty: 3758 Ship Ammo Qty: 18 Resupply Ship T_AKE_4 Resupply Fuel Qty: 2789 Resupply Ammo Qty: 5834
# Time: 365.03642304073594 Event: Fuel Needed Ship DDG_63 Ship Fuel Qty: 0 Ship Ammo Qty: 26 Resupply Ship T_AOE_6 Resupply Fuel Qty: 138526 Resupply Ammo Qty: 1444
# Time: 377.789424895273 Event: Resupplying Resupply Ship NA Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship T_AKE_4 Resupply Fuel Qty: 23450 Resupply Ammo Qty: 6000
# Time: 385.20341733835465 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 386.20341733835465 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 387.20341733835465 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 388.20341733835465 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 389.15407156027686 Event: Resupply Available Ship NA Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship T_AKE_4 Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 389.20341733835465 Event: !!Not big enough!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 390.20341733835465 Event: !!Not big enough!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 391.20341733835465 Event: !!Not big enough!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 392.20341733835465 Event: !!Not big enough!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 393.20341733835465 Event: !!Not big enough!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 394.20341733835465 Event: !!Not big enough!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 395.20341733835465 Event: !!Not big enough!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 396.20341733835465 Event: !!Not big enough!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 397.20341733835465 Event: !!Not big enough!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 398.20341733835465 Event: !!Not big enough!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 399.20341733835465 Event: !!Not big enough!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 400.20341733835465 Event: !!Not big enough!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 401.20341733835465 Event: !!Not big enough!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 402.20341733835465 Event: !!Not big enough!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 403.20341733835465 Event: !!Not big enough!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 404.20341733835465 Event: !!Not big enough!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 405.20341733835465 Event: !!Not big enough!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 406.20341733835465 Event: !!Not big enough!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 407.20341733835465 Event: !!Not big enough!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 408.20341733835465 Event: !!Not big enough!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 409.0988692148727 Event: Resupply Under Way Ship DDG_63 Ship Fuel Qty: 2629 Ship Ammo Qty: 26 Resupply Ship T_AOE_6 Resupply Fuel Qty: 135897 Resupply Ammo Qty: 1418
# Time: 409.20341733835465 Event: !!Not big enough!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 410.20341733835465 Event: !!Not big enough!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 411.20341733835465 Event: !!Not big enough!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 412.20341733835465 Event: !!Not big enough!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 412.2688248560156 Event: Patrolling Ship DDG_63 Ship Fuel Qty: 2629 Ship Ammo Qty: 26 Resupply Ship T_AOE_6 Resupply Fuel Qty: 135897 Resupply Ammo Qty: 1418
# Time: 413.20341733835465 Event: Fuel Needed Ship CSG Ship Fuel Qty: 0 Ship Ammo Qty: 268 Resupply Ship T_AOE_6 Resupply Fuel Qty: 135897 Resupply Ammo Qty: 1418
# Time: 424.43325869373075 Event: Fuel Needed Ship DDG_89 Ship Fuel Qty: 0 Ship Ammo Qty: 26 Resupply Ship T_AKE_4 Resupply Fuel Qty: 23450 Resupply Ammo Qty: 6000
# Time: 446.72094562115285 Event: Resupply Under Way Ship DDG_89 Ship Fuel Qty: 2629 Ship Ammo Qty: 26 Resupply Ship T_AKE_4 Resupply Fuel Qty: 20821 Resupply Ammo Qty: 5974
# Time: 450.7911755190893 Event: Resupply Under Way Ship CSG Ship Fuel Qty: 25700 Ship Ammo Qty: 268 Resupply Ship T_AOE_6 Resupply Fuel Qty: 110197 Resupply Ammo Qty: 1150
# Time: 451.0984383211296 Event: Patrolling Ship DDG_89 Ship Fuel Qty: 2629 Ship Ammo Qty: 26 Resupply Ship T_AKE_4 Resupply Fuel Qty: 20821 Resupply Ammo Qty: 5974
# Time: 453.22864170003044 Event: Fuel Needed Ship DDG_85 Ship Fuel Qty: 0 Ship Ammo Qty: 26 Resupply Ship T_AKE_4 Resupply Fuel Qty: 20821 Resupply Ammo Qty: 5974
# Time: 454.8224788708832 Event: Patrolling Ship CSG Ship Fuel Qty: 25700 Ship Ammo Qty: 268 Resupply Ship T_AOE_6 Resupply Fuel Qty: 110197 Resupply Ammo Qty: 1150
# Time: 471.1550144202105 Event: Resupply Under Way Ship DDG_85 Ship Fuel Qty: 2629 Ship Ammo Qty: 26 Resupply Ship T_AKE_4 Resupply Fuel Qty: 18192 Resupply Ammo Qty: 5948
# Time: 475.68166825361135 Event: Patrolling Ship DDG_85 Ship Fuel Qty: 2629 Ship Ammo Qty: 26 Resupply Ship T_AKE_4 Resupply Fuel Qty: 18192 Resupply Ammo Qty: 5948
# Time: 498.6235012380443 Event: Fuel Needed Ship DDG_62 Ship Fuel Qty: 0 Ship Ammo Qty: 26 Resupply Ship T_AKE_4 Resupply Fuel Qty: 18192 Resupply Ammo Qty: 5948
# Time: 506.1291519568606 Event: Fuel Needed Ship CG_67 Ship Fuel Qty: 0 Ship Ammo Qty: 18 Resupply Ship T_AOE_6 Resupply Fuel Qty: 110197 Resupply Ammo Qty: 1150
# Time: 540.0445180544266 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 541.0445180544266 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 542.0445180544266 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 543.0445180544266 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 544.0445180544266 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 545.0445180544266 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 546.0445180544266 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 547.0445180544266 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 547.5856899213015 Event: Resupply Under Way Ship CG_67 Ship Fuel Qty: 3758 Ship Ammo Qty: 18 Resupply Ship T_AOE_6 Resupply Fuel Qty: 106439 Resupply Ammo Qty: 1132
# Time: 548.0445180544266 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 549.0445180544266 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 549.8824250059561 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 550.0445180544266 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 550.8824250059561 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 551.0445180544266 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 551.7641515751043 Event: Patrolling Ship CG_67 Ship Fuel Qty: 3758 Ship Ammo Qty: 18 Resupply Ship T_AOE_6 Resupply Fuel Qty: 106439 Resupply Ammo Qty: 1132
# Time: 551.8824250059561 Event: Fuel Needed Ship DDG_63 Ship Fuel Qty: 0 Ship Ammo Qty: 26 Resupply Ship T_AOE_6 Resupply Fuel Qty: 106439 Resupply Ammo Qty: 1132
# Time: 552.0445180544266 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 553.0445180544266 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 554.0445180544266 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 554.9491922243342 Event: Resupply Under Way Ship DDG_62 Ship Fuel Qty: 2629 Ship Ammo Qty: 26 Resupply Ship T_AKE_4 Resupply Fuel Qty: 15563 Resupply Ammo Qty: 5922
# Time: 555.0445180544266 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 556.0445180544266 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 557.0445180544266 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 558.0445180544266 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 559.0445180544266 Event: !!Resupply Unavailable!! Ship CG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 559.5150419530233 Event: Patrolling Ship DDG_62 Ship Fuel Qty: 2629 Ship Ammo Qty: 26 Resupply Ship T_AKE_4 Resupply Fuel Qty: 15563 Resupply Ammo Qty: 5922
# Time: 560.0445180544266 Event: Fuel Needed Ship CG_62 Ship Fuel Qty: 0 Ship Ammo Qty: 18 Resupply Ship T_AKE_4 Resupply Fuel Qty: 15563 Resupply Ammo Qty: 5922
# Time: 581.5040665839332 Event: Resupply Under Way Ship DDG_63 Ship Fuel Qty: 2629 Ship Ammo Qty: 26 Resupply Ship T_AOE_6 Resupply Fuel Qty: 103810 Resupply Ammo Qty: 1106
# Time: 585.7778424647282 Event: Patrolling Ship DDG_63 Ship Fuel Qty: 2629 Ship Ammo Qty: 26 Resupply Ship T_AOE_6 Resupply Fuel Qty: 103810 Resupply Ammo Qty: 1106
# Time: 602.0206958976233 Event: Resupply Under Way Ship CG_62 Ship Fuel Qty: 3758 Ship Ammo Qty: 18 Resupply Ship T_AKE_4 Resupply Fuel Qty: 11805 Resupply Ammo Qty: 5904
# Time: 606.2541811035904 Event: Patrolling Ship CG_62 Ship Fuel Qty: 3758 Ship Ammo Qty: 18 Resupply Ship T_AKE_4 Resupply Fuel Qty: 11805 Resupply Ammo Qty: 5904
# Time: 609.0416614804235 Event: Fuel Needed Ship DDG_89 Ship Fuel Qty: 0 Ship Ammo Qty: 26 Resupply Ship T_AOE_6 Resupply Fuel Qty: 103810 Resupply Ammo Qty: 1106
# Time: 611.1330008180911 Event: !!Not big enough!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 612.1330008180911 Event: !!Not big enough!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 613.1330008180911 Event: !!Not big enough!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 614.1330008180911 Event: !!Not big enough!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 615.1330008180911 Event: !!Not big enough!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 615.3610639045181 Event: Fuel Needed Ship DDG_85 Ship Fuel Qty: 0 Ship Ammo Qty: 26 Resupply Ship T_AKE_4 Resupply Fuel Qty: 11805 Resupply Ammo Qty: 5904
# Time: 616.1330008180911 Event: !!Resupply Unavailable!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# ...
# Time: 1179.9302529353597 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1180.9302529353597 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1181.9302529353597 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1182.9302529353597 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1183.9302529353597 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1184.9302529353597 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1185.9302529353597 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1186.9302529353597 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1187.9302529353597 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1188.9302529353597 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1189.9302529353597 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1190.9302529353597 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1191.9302529353597 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1192.9302529353597 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1193.9302529353597 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1194.9302529353597 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1195.9302529353597 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1196.9302529353597 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1197.9302529353597 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1198.9302529353597 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1199.6818922429222 Event: Resupply Under Way Ship DDG_85 Ship Fuel Qty: 2629 Ship Ammo Qty: 26 Resupply Ship T_AKE_4 Resupply Fuel Qty: 18192 Resupply Ammo Qty: 5948
# Time: 1199.9302529353597 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1200.9302529353597 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1201.9302529353597 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1202.9302529353597 Event: !!Resupply Unavailable!! Ship DDG_62 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1203.3238876037772 Event: Patrolling Ship DDG_85 Ship Fuel Qty: 2629 Ship Ammo Qty: 26 Resupply Ship T_AKE_4 Resupply Fuel Qty: 18192 Resupply Ammo Qty: 5948
# Time: 1203.9302529353597 Event: Fuel Needed Ship DDG_62 Ship Fuel Qty: 0 Ship Ammo Qty: 26 Resupply Ship T_AKE_4 Resupply Fuel Qty: 18192 Resupply Ammo Qty: 5948
# Time: 1206.91147908896 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1207.91147908896 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1208.91147908896 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1209.4869117378412 Event: Resupply Under Way Ship CG_62 Ship Fuel Qty: 3758 Ship Ammo Qty: 18 Resupply Ship T_AOE_6 Resupply Fuel Qty: 138526 Resupply Ammo Qty: 1444
# Time: 1209.91147908896 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1210.91147908896 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1211.91147908896 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1212.91147908896 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1213.6660037813103 Event: Patrolling Ship CG_62 Ship Fuel Qty: 3758 Ship Ammo Qty: 18 Resupply Ship T_AOE_6 Resupply Fuel Qty: 138526 Resupply Ammo Qty: 1444
# Time: 1213.91147908896 Event: Fuel Needed Ship CG_67 Ship Fuel Qty: 0 Ship Ammo Qty: 18 Resupply Ship T_AOE_6 Resupply Fuel Qty: 138526 Resupply Ammo Qty: 1444
# Time: 1229.3182641311855 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1230.3182641311855 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1231.3182641311855 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1232.3182641311855 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1232.54244749131 Event: Resupply Under Way Ship DDG_62 Ship Fuel Qty: 2629 Ship Ammo Qty: 26 Resupply Ship T_AKE_4 Resupply Fuel Qty: 15563 Resupply Ammo Qty: 5922
# Time: 1233.3182641311855 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1234.3182641311855 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1235.3182641311855 Event: !!Resupply Unavailable!! Ship DDG_63 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1236.0892188152982 Event: Patrolling Ship DDG_62 Ship Fuel Qty: 2629 Ship Ammo Qty: 26 Resupply Ship T_AKE_4 Resupply Fuel Qty: 15563 Resupply Ammo Qty: 5922
# Time: 1236.3182641311855 Event: Fuel Needed Ship DDG_63 Ship Fuel Qty: 0 Ship Ammo Qty: 26 Resupply Ship T_AKE_4 Resupply Fuel Qty: 15563 Resupply Ammo Qty: 5922
# Time: 1251.5398395781226 Event: Resupply Under Way Ship DDG_63 Ship Fuel Qty: 2629 Ship Ammo Qty: 26 Resupply Ship T_AKE_4 Resupply Fuel Qty: 12934 Resupply Ammo Qty: 5896
# Time: 1255.0840227353633 Event: Resupply Under Way Ship CG_67 Ship Fuel Qty: 3758 Ship Ammo Qty: 18 Resupply Ship T_AOE_6 Resupply Fuel Qty: 134768 Resupply Ammo Qty: 1426
# Time: 1255.7561613769842 Event: Patrolling Ship DDG_63 Ship Fuel Qty: 2629 Ship Ammo Qty: 26 Resupply Ship T_AKE_4 Resupply Fuel Qty: 12934 Resupply Ammo Qty: 5896
# Time: 1259.5088780023368 Event: Patrolling Ship CG_67 Ship Fuel Qty: 3758 Ship Ammo Qty: 18 Resupply Ship T_AOE_6 Resupply Fuel Qty: 134768 Resupply Ammo Qty: 1426
# Time: 1270.4700369869943 Event: Fuel Needed Ship DDG_89 Ship Fuel Qty: 0 Ship Ammo Qty: 26 Resupply Ship T_AOE_6 Resupply Fuel Qty: 134768 Resupply Ammo Qty: 1426
# Time: 1290.7825323878333 Event: !!Not big enough!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1291.7048792539363 Event: Resupply Under Way Ship DDG_89 Ship Fuel Qty: 2629 Ship Ammo Qty: 26 Resupply Ship T_AOE_6 Resupply Fuel Qty: 132139 Resupply Ammo Qty: 1400
# Time: 1291.7825323878333 Event: !!Not big enough!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1292.7825323878333 Event: !!Not big enough!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1293.7825323878333 Event: !!Not big enough!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1294.7825323878333 Event: !!Not big enough!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1295.7825323878333 Event: !!Not big enough!! Ship CSG Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1296.036064832092 Event: Patrolling Ship DDG_89 Ship Fuel Qty: 2629 Ship Ammo Qty: 26 Resupply Ship T_AOE_6 Resupply Fuel Qty: 132139 Resupply Ammo Qty: 1400
# Time: 1296.7825323878333 Event: Fuel Needed Ship CSG Ship Fuel Qty: 0 Ship Ammo Qty: 268 Resupply Ship T_AOE_6 Resupply Fuel Qty: 132139 Resupply Ammo Qty: 1400
# Time: 1332.6712202904837 Event: Resupply Under Way Ship CSG Ship Fuel Qty: 25700 Ship Ammo Qty: 268 Resupply Ship T_AOE_6 Resupply Fuel Qty: 106439 Resupply Ammo Qty: 1132
# Time: 1337.870664504914 Event: Patrolling Ship CSG Ship Fuel Qty: 25700 Ship Ammo Qty: 268 Resupply Ship T_AOE_6 Resupply Fuel Qty: 106439 Resupply Ammo Qty: 1132
# Time: 1338.173887250976 Event: Fuel Needed Ship DDG_85 Ship Fuel Qty: 0 Ship Ammo Qty: 26 Resupply Ship T_AKE_4 Resupply Fuel Qty: 12934 Resupply Ammo Qty: 5896
# Time: 1354.4407535431344 Event: Resupply Under Way Ship DDG_85 Ship Fuel Qty: 2629 Ship Ammo Qty: 26 Resupply Ship T_AKE_4 Resupply Fuel Qty: 10305 Resupply Ammo Qty: 5870
# Time: 1360.3110474968353 Event: Patrolling Ship DDG_85 Ship Fuel Qty: 2629 Ship Ammo Qty: 26 Resupply Ship T_AKE_4 Resupply Fuel Qty: 10305 Resupply Ammo Qty: 5870
# Time: 1360.8555910195994 Event: Fuel Needed Ship CG_62 Ship Fuel Qty: 0 Ship Ammo Qty: 18 Resupply Ship T_AKE_4 Resupply Fuel Qty: 10305 Resupply Ammo Qty: 5870
# Time: 1366.4535177574096 Event: Fuel Needed Ship DDG_62 Ship Fuel Qty: 0 Ship Ammo Qty: 26 Resupply Ship T_AOE_6 Resupply Fuel Qty: 106439 Resupply Ammo Qty: 1132
# Time: 1376.4588409294006 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1377.4588409294006 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1378.4588409294006 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1379.4588409294006 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1380.4588409294006 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1381.4588409294006 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1382.4588409294006 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1383.4588409294006 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1384.4588409294006 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1385.4588409294006 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1386.4588409294006 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1387.4588409294006 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1388.4588409294006 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1388.7006797268687 Event: Resupply Under Way Ship DDG_62 Ship Fuel Qty: 2629 Ship Ammo Qty: 26 Resupply Ship T_AOE_6 Resupply Fuel Qty: 103810 Resupply Ammo Qty: 1106
# Time: 1389.4588409294006 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1390.4588409294006 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1391.4588409294006 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1392.4588409294006 Event: !!Resupply Unavailable!! Ship CG_67 Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship NA Resupply Fuel Qty: NA Resupply Ammo Qty: NA
# Time: 1393.246624074085 Event: Patrolling Ship DDG_62 Ship Fuel Qty: 2629 Ship Ammo Qty: 26 Resupply Ship T_AOE_6 Resupply Fuel Qty: 103810 Resupply Ammo Qty: 1106
# Time: 1393.4588409294006 Event: Fuel Needed Ship CG_67 Ship Fuel Qty: 0 Ship Ammo Qty: 18 Resupply Ship T_AOE_6 Resupply Fuel Qty: 103810 Resupply Ammo Qty: 1106
# Time: 1396.5712456242231 Event: Resupply Under Way Ship CG_62 Ship Fuel Qty: 3758 Ship Ammo Qty: 18 Resupply Ship T_AKE_4 Resupply Fuel Qty: 6547 Resupply Ammo Qty: 5852
# Time: 1400.8497244266298 Event: Patrolling Ship CG_62 Ship Fuel Qty: 3758 Ship Ammo Qty: 18 Resupply Ship T_AKE_4 Resupply Fuel Qty: 6547 Resupply Ammo Qty: 5852
# Time: 1406.1009211325736 Event: Fuel Needed Ship DDG_63 Ship Fuel Qty: 0 Ship Ammo Qty: 26 Resupply Ship T_AKE_4 Resupply Fuel Qty: 6547 Resupply Ammo Qty: 5852
# Time: 1412.7416361301548 Event: Resupply Under Way Ship CG_67 Ship Fuel Qty: 3758 Ship Ammo Qty: 18 Resupply Ship T_AOE_6 Resupply Fuel Qty: 100052 Resupply Ammo Qty: 1088
# Time: 1417.255333513756 Event: Patrolling Ship CG_67 Ship Fuel Qty: 3758 Ship Ammo Qty: 18 Resupply Ship T_AOE_6 Resupply Fuel Qty: 100052 Resupply Ammo Qty: 1088
# Time: 1427.4900786234086 Event: Resupply Under Way Ship DDG_63 Ship Fuel Qty: 2629 Ship Ammo Qty: 26 Resupply Ship T_AKE_4 Resupply Fuel Qty: 3918 Resupply Ammo Qty: 5826
# Time: 1431.8101301674656 Event: Return to Base Ship NA Ship Fuel Qty: NA Ship Ammo Qty: NA Resupply Ship T_AKE_4 Resupply Fuel Qty: 3918 Resupply Ammo Qty: 5826
# Time: 1431.8101301674656 Event: Patrolling Ship DDG_63 Ship Fuel Qty: 2629 Ship Ammo Qty: 26 Resupply Ship T_AKE_4 Resupply Fuel Qty: 3918 Resupply Ammo Qty: 5826
